# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
path="/home/rishav/LISAHierarchicalTriples/final_results/inj_final_75_0_ospe.txt"
data = np.loadtxt(path)
data
# Out:
# array([[ 0.00000000e+00,  1.00000000e-02,  1.00000000e-03, ...,
#          1.77500000e-03,  8.90000000e+01,  0.00000000e+00],
#        [ 1.00000000e-03,  1.00000000e-02,  1.00000000e-03, ...,
#          1.77500000e-03,  8.90000000e+01, -2.00000000e-04],
#        [ 1.00000000e-03,  1.00000000e-02,  1.00000000e-03, ...,
#          1.77500000e-03,  8.90000000e+01, -2.00000000e-04],
#        ...,
#        [ 2.26099000e+02,  4.43360000e-02,  1.00000000e-03, ...,
#          5.80000000e-05,  7.93945280e+01, -1.64180909e+03],
#        [ 2.26099000e+02,  4.43360000e-02,  1.00000000e-03, ...,
#          5.80000000e-05,  7.93945280e+01, -1.64180909e+03],
#        [ 2.26100000e+02,  3.06640000e-02,  1.00000000e-03, ...,
#          5.20000000e-05,  7.93945280e+01, -1.64180909e+03]],
#       shape=(452200, 10))

# %% [markdown]
# The iniital conditions are:
# __m1(Msun)_______m2(Msun)___________m3(Msun)________a1(au)______a2(au)____e1____e2____g1(deg)__g2(deg)__i(deg)__age(Myr)___Omega1(deg)____ :::
#
# :: the eps is 1.e-16. I know that this is VERY small. DO NOT CHANGE it.
# This value has been tested to give the best conservation of SMA. changing it will give wrong results!!
#
# This file is very useful for turning on/off the quadrupole-level, octupole-level  GR effects and GW.
#
# #############################octupole.c########################################
# octupole.c is a key component of the integration scheme and shows how the orbital parameters are evolved in each time step.
#
# #############################HTI.h#############################################
# HTI.h is very useful for turning on/off the quadrupole-level, octupole-level and GR effects. By default, they are all on. To turn any given one off, simply go to their definition (lines 18-20) and comment it out. This turns off the effect that this term has on the evolution of the system. Conversely, to turn the effect back on, simply uncomment out the defintion.
#
# ##############################HTI.print.c###########################################
# HTI.c is what actually runs the integration and prints out the results. It is useful if one desires to change the form of the output.
#
# #############################Compiling and Running#############################
# Compiling OSPE is as simple as using the make command, whih runs the Makefile that accompanies the program. This creates the executable octupole which can be run simply by ./octupole. By default, this just prints out the results to the screen. To put it in a file just run ./octupole > filename.txt
#
# ##### this is an inclination version
# here instead of the usual 4 parameter form Frod et al 2000 I integrate over 7 parameter to check the inclinations of the inner outer and mutual inclinations. Assume only total angular momenutm conservation. This version has been check in the 4 order for Fabrytcky configurations inclinations, and compar to analytical claculations for e_{max,min} and i_{min,max}
# The initial inner and outer inclinations are set by the total angular momentum and the mutual inclination.
#
# ################### output ##############################
#
# t[yr] ,e1,e2,g1[rad],g2[rad],a1[au],i1*180./M_PI,i2*180./M_PI,i*180./M_PI)

# %%
labels = ['e1', 'e2', 'g1 [rad]', 'g2 [rad]', 'a1 [au]', 
          'i1 [deg]', 'i2 [deg]', 'i [deg]']

# Create subplots (8 rows, 1 column)
fig, axes = plt.subplots(8, 1, figsize=(10, 16), sharex=True)

# Plot each parameter
for i in range(8):
    axes[i].plot(data[:, 0], data[:, i + 1])
    axes[i].set_ylabel(labels[i])
    axes[i].grid(True)

# Common x-label
axes[-1].set_xlabel('t [yr]')

plt.suptitle('Orbital Parameter Evolution Over Time for Semi-major Axis 75 au', fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.97])
plt.show()

# %%
path="/home/rishav/LISAHierarchicalTriples/final_results/inj_final_75_1_ospe.txt"
data = np.loadtxt(path)
fig, axes = plt.subplots(8, 1, figsize=(10, 16), sharex=True)

# Plot each parameter
for i in range(8):
    axes[i].plot(data[:, 0], data[:, i + 1])
    axes[i].set_ylabel(labels[i])
    axes[i].grid(True)

# Common x-label
axes[-1].set_xlabel('t [yr]')

plt.suptitle('Orbital Parameter Evolution Over Time for Semi-major Axis 75 au, eccentricity 0.3', fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.97])
plt.show()

# %%
path="/home/rishav/LISAHierarchicalTriples/final_results/inj_final_200_0_ospe.txt"
labels = ['e1', 'e2', 'g1 [rad]', 'g2 [rad]', 'a1 [au]', 
          'i1 [deg]', 'i2 [deg]', 'i [deg]']
data = np.loadtxt(path)
fig, axes = plt.subplots(8, 1, figsize=(10, 16), sharex=True)

# Plot each parameter
for i in range(8):
    axes[i].plot(data[:, 0], data[:, i + 1])
    axes[i].set_ylabel(labels[i])
    axes[i].grid(True)

# Common x-label
axes[-1].set_xlabel('t [yr]')

plt.suptitle('Orbital Parameter Evolution Over Time for Semi-major Axis 200 au', fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.97])
plt.show()

# %%
path="/home/rishav/LISAHierarchicalTriples/final_results/inj_final_200_1_ospe.txt"
data = np.loadtxt(path)
labels = ['e1', 'e2', 'g1 [rad]', 'g2 [rad]', 'a1 [au]', 
          'i1 [deg]', 'i2 [deg]', 'i [deg]']
fig, axes = plt.subplots(8, 1, figsize=(10, 16), sharex=True)

# Plot each parameter
for i in range(8):
    axes[i].plot(data[:, 0], data[:, i + 1])
    axes[i].set_ylabel(labels[i])
    axes[i].grid(True)

# Common x-label
axes[-1].set_xlabel('t [yr]')

plt.suptitle('Orbital Parameter Evolution Over Time for Semi-major Axis 200 au eccentricity 0.3', fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.97])
plt.show()

# %%
path="/home/rishav/LISAHierarchicalTriples/final_results/inj_final_350_0_ospe.txt"
data = np.loadtxt(path)
labels = ['e1', 'e2', 'g1 [rad]', 'g2 [rad]', 'a1 [au]', 
          'i1 [deg]', 'i2 [deg]', 'i [deg]']
fig, axes = plt.subplots(8, 1, figsize=(10, 16), sharex=True)

# Plot each parameter
for i in range(8):
    axes[i].plot(data[:, 0], data[:, i + 1])
    axes[i].set_ylabel(labels[i])
    axes[i].grid(True)

# Common x-label
axes[-1].set_xlabel('t [yr]')

plt.suptitle('Orbital Parameter Evolution Over Time for Semi-major Axis 350 au eccentricity 0.1', fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.97])
plt.show()

# %%
path="/home/rishav/LISAHierarchicalTriples/final_results/inj_final_350_1_ospe.txt"
data = np.loadtxt(path)
labels = ['e1', 'e2', 'g1 [rad]', 'g2 [rad]', 'a1 [au]', 
          'i1 [deg]', 'i2 [deg]', 'i [deg]']
fig, axes = plt.subplots(8, 1, figsize=(10, 16), sharex=True)

# Plot each parameter
for i in range(8):
    axes[i].plot(data[:, 0], data[:, i + 1])
    axes[i].set_ylabel(labels[i])
    axes[i].grid(True)

# Common x-label
axes[-1].set_xlabel('t [yr]')

plt.suptitle('Orbital Parameter Evolution Over Time for Semi-major Axis 350 au eccentricity 0.3', fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.97])
plt.show()
