# %%
import json
import matplotlib.pyplot as plt

# %%
parameters=['t_shifted','argp_inner','argp_outer','inc_outer']

# %%
file_path="inj_final_100_0_low_inclin_00/inj_final_100_00_ospe_orbit_param.json"

with open(file_path, 'r') as f:
    data = json.load(f)

# data

# %%
plt.plot(data[parameters[0]],data[parameters[3]])
